# %% [markdown]
# Plotly in not much different from matplotlib and seaborn but it is slighly because of some graph

# %%
# We can't use the pyplot in this pwskills lab so use google collab
#Collab is a offereing from google where we can run our code inside a notebook

# %%
### Pyplot  gives better interactiveness than matplotlib and seaborn

# %% [markdown]
# ![image.png](attachment:4a883edd-ff71-4d7d-828d-a5fba4ee0ebc.png)

# %% [markdown]
# ![image.png](attachment:03e94030-4cce-4338-9b52-1d0a9471ffa4.png)

# %% [markdown]
# ![image.png](attachment:a90776ca-e8ca-4cbe-bb1c-fa08a9b5d572.png)

# %% [markdown]
# ![image.png](attachment:85776710-efe0-426a-9ffc-1dc6cb630265.png)

# %% [markdown]
# ![image.png](attachment:c234471a-da2e-4935-bfda-21f4e2a64165.png)

# %% [markdown]
# ![image.png](attachment:625fcf2e-9d19-449b-a56f-2dc759011ca4.png)

# %% [markdown]
# ![image.png](attachment:d45123bc-06fd-4ac6-be95-787dbd951b0a.png)

# %% [markdown]
# ![image.png](attachment:061f8437-e45b-4891-8585-7a01047f4169.png)
#
# ![image.png](attachment:bb5ea54f-719c-4f89-98b7-18b27d89a5d9.png)

# %% [markdown]
# ![image.png](attachment:c06e2dec-6b1c-4198-8a2d-c7a4e595eef5.png)

# %% [markdown]
# ![image.png](attachment:291b6494-a8ca-45d5-8e7d-c2a899c3e70a.png)

# %% [markdown]
# ![image.png](attachment:8870455c-fd3a-42bd-863e-92581d198087.png)

# %% [markdown]
# ![image.png](attachment:833d1b11-ebb9-4784-b5c7-9eab57d31105.png)

# %% [markdown]
# ![image.png](attachment:41efc545-061d-45c1-bd19-9911f4b29300.png)
