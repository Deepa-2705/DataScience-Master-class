# %% [markdown]
# ## Pandas library : We can read a data ,manipulate data ,we can perform feature engineering ,eda process

# %%
# Pandas always works with structured data (tabular data

# %%
import pandas as pd

# %%
pd.read_csv('Mall_Customers.csv')
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
pd.read_csv('Mall_Customers.csv',header=None)   #Table with no header
# Out:
#               0       1    2                   3                       4
# 0    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 1             1    Male   19                  15                      39
# 2             2    Male   21                  15                      81
# 3             3  Female   20                  16                       6
# 4             4  Female   23                  16                      77
# ..          ...     ...  ...                 ...                     ...
# 196         196  Female   35                 120                      79
# 197         197  Female   45                 126                      28
# 198         198    Male   32                 126                      74
# 199         199    Male   32                 137                      18
# 200         200    Male   30                 137                      83
#
# [201 rows x 5 columns]

# %%
df=pd.read_csv('Mall_Customers.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# In pandas there are 2 types of datatypes : Dataframe and Series

#Dataframe is a table consists of rows and columns 
#series is a kind of list it displays the index along with data 
# single row or single column is a series

# %%
list(df.columns)   #List of all the columns present
# Out:
# ['CustomerID', 'Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
df.head()   #By default head will print only 5 rows
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail(7)   #It will gives rows from last till given number
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.dtypes  # It will return the columns along with their respective datatypes

# Object  datatypes in pandas is equivalent to the string in core
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
#Select one columns 
df['Age']    #It will print the all data of this column
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
type(df['Age'])  #This is a series 
#series is equivalent to the list
# Out:
# pandas.core.series.Series

# %%
list(df['Age'])  #convert series into list
# Out:
# [19,
#  21,
#  20,
#  23,
#  31,
#  22,
#  35,
#  23,
#  64,
#  30,
#  67,
#  35,
#  58,
#  24,
#  37,
#  22,
#  35,
#  20,
#  52,
#  35,
#  35,
#  25,
#  46,
#  31,
#  54,
#  29,
#  45,
#  35,
#  40,
#  23,
#  60,
#  21,
#  53,
#  18,
#  49,
#  21,
#  42,
#  30,
#  36,
#  20,
#  65,
#  24,
#  48,
#  31,
#  49,
#  24,
#  50,
#  27,
#  29,
#  31,
#  49,
#  33,
#  31,
#  59,
#  50,
#  47,
#  51,
#  69,
#  27,
#  53,
#  70,
#  19,
#  67,
#  54,
#  63,
#  18,
#  43,
#  68,
#  19,
#  32,
#  70,
#  47,
#  60,
#  60,
#  59,
#  26,
#  45,
#  40,
#  23,
#  49,
#  57,
#  38,
#  67,
#  46,
#  21,
#  48,
#  55,
#  22,
#  34,
#  50,
#  68,
#  18,
#  48,
#  40,
#  32,
#  24,
#  47,
#  27,
#  48,
#  20,
#  23,
#  49,
#  67,
#  26,
#  49,
#  21,
#  66,
#  54,
#  68,
#  66,
#  65,
#  19,
#  38,
#  19,
#  18,
#  19,
#  63,
#  49,
#  51,
#  50,
#  27,
#  38,
#  40,
#  39,
#  23,
#  31,
#  43,
#  40,
#  59,
#  38,
#  47,
#  39,
#  25,
#  31,
#  20,
#  29,
#  44,
#  32,
#  19,
#  35,
#  57,
#  32,
# ...

# %% [markdown]
# ### Observation

# %%
df[['Age']] # Put the single column inside the list
# Out:
#      Age
# 0     19
# 1     21
# 2     20
# 3     23
# 4     31
# ..   ...
# 195   35
# 196   45
# 197   32
# 198   32
# 199   30
#
# [200 rows x 1 columns]

# %%
type(df[['Age']])   #Now this is not series its a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# The dataframe and the series have different different functionalities

# %%
# we cannot select multiple columns or rows as series 
df['Age','Genre']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Age', 'Genre')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
#But we can select multiple rows and columns as dataframe
df[['Age','Genre']]
# Out:
#      Age   Genre
# 0     19    Male
# 1     21    Male
# 2     20  Female
# 3     23  Female
# 4     31  Female
# ..   ...     ...
# 195   35  Female
# 196   45  Female
# 197   32    Male
# 198   32    Male
# 199   30    Male
#
# [200 rows x 2 columns]

# %%
pd.read_excel('RandomData.xlsx')
# Out:
#   Tickers            Eps  Revenue Price         People
# 0  Google          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    Msft             -1       85    64     bill gates
# 3     Ril  Not Available       50  1023  mukesh ambani
# 4    Tata            5.6       -1  n.a.     ratan tata

# %%
#We can also select the data accordin to the sheet number in the excel workbook
#By passing argument like sheetname= 'Sheetname'

# %%
df1=pd.read_excel('RandomData.xlsx')

# %%
df1
# Out:
#   Tickers            Eps  Revenue Price         People
# 0  Google          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    Msft             -1       85    64     bill gates
# 3     Ril  Not Available       50  1023  mukesh ambani
# 4    Tata            5.6       -1  n.a.     ratan tata

# %%
df1.head(3)
# Out:
#   Tickers    Eps  Revenue Price      People
# 0  Google  27.82       87   845  larry page
# 1     WMT   4.61      484    65        n.a.
# 2    Msft     -1       85    64  bill gates

# %%
df1.tail()
# Out:
#   Tickers            Eps  Revenue Price         People
# 0  Google          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    Msft             -1       85    64     bill gates
# 3     Ril  Not Available       50  1023  mukesh ambani
# 4    Tata            5.6       -1  n.a.     ratan tata

# %%
df1.dtypes
# Out:
# Tickers    object
# Eps        object
# Revenue     int64
# Price      object
# People     object
# dtype: object

# %%
df1['Tickers']
# Out:
# 0    Google
# 1       WMT
# 2      Msft
# 3       Ril
# 4      Tata
# Name: Tickers, dtype: object

# %%
type(df1['Tickers'])
# Out:
# pandas.core.series.Series

# %%
df1[['Tickers','Revenue']]
# Out:
#   Tickers  Revenue
# 0  Google       87
# 1     WMT      484
# 2    Msft       85
# 3     Ril       50
# 4    Tata       -1

# %%
#Read data using a link on internet

# %%
df2=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
# If we want this data again then we have to again search for that link.
# Instead we will save that inside our directory (local system)

# %%
df2.to_csv('titanic_data.csv')   #It store the index no also which is not a data so remove it

# %%
df2.to_csv('titanic_data.csv',index=False)

# %%
# https://www.basketball-reference.com/leagues/NBA_2015_totals.html
# In this web page there are various data
#We have to extract only the tabular data from the webpage as pandas can only reads tabular data

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 57.7 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml  #This modult help us in reading html data 
import pandas as pd
pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

#This will onlt read the tabular data nothing else
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
url_data=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(url_data)  #The pandas stores the data avilable on the link as a list
# Out:
# list

# %% [markdown]
# #### Why its giving list it should give the dataframe
#
# Its is because as on the link provided there could be a 0 table or thousand or more table.
# Pandas will get all the table and put them inside the list (one table will be one data) .we can read any table .

# %%
len(url_data)  #No of table on the html page
# Out:
# 1

# %%
url_data[0]   #This is the dtaset
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df4=url_data[0]

# %%
df4.head(7)
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
# 5  5  Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21  159
# 6  5  Arron Afflalo  SG  29  POR  25  19   752   94  227  ...  .851    6   61
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
# 5  180  101  32   5   83  108   771
# 6   67   28   9   2   33   59   264
#
# [7 rows x 30 columns]

# %%
#Save the html file in local 
df4.to_csv('Url_data.csv',index=False)
