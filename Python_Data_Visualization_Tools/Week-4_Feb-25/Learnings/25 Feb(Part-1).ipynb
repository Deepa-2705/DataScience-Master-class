# %%
l=['a','b','c','d','e','f']

# %%
#Convert this list in series 
import pandas as pd
s=pd.Series(l)

# %%
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# 5    f
# dtype: object

# %%
#convert the series into the list 
list(s)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
s1=df['Name'][2:11]

# %%
s1
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
# Rename the indices as per our choice
pd.Series(list(df['Name'][2:11]),index=['a','b','c','d','e','f','g','h','i'])
# Out:
# a                               Heikkinen, Miss. Laina
# b         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                             Allen, Mr. William Henry
# d                                     Moran, Mr. James
# e                              McCarthy, Mr. Timothy J
# f                       Palsson, Master. Gosta Leonard
# g    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# h                  Nasser, Mrs. Nicholas (Adele Achem)
# i                      Sandstrom, Miss. Marguerite Rut
# dtype: object

# %%
pd.Series(df['Name'][2:11],index=['a','b','c','d','e','f','g','h','i'])
#It is necessary to put the list because the df['Name'] is already a series having index already.
# we can put another index on a series  (change it to list first then add custom index) 
# If we try to change index it will nullify the series
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# e    NaN
# f    NaN
# g    NaN
# h    NaN
# i    NaN
# Name: Name, dtype: object

# %%
s1
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
s2=df['Name'][11:16]

# %%
s2
# Out:
# 11                Bonnell, Miss. Elizabeth
# 12          Saundercock, Mr. William Henry
# 13             Andersson, Mr. Anders Johan
# 14    Vestrom, Miss. Hulda Amanda Adolfina
# 15        Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %%
#Now add the indices
s1+s2  #It will add the indices but it will nullify the series
# Out:
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# Name: Name, dtype: object

# %%
#Instead of cancatination we use append
s1.append(s2)   #It will bring both the series together
# Out:
# /tmp/ipykernel_1343/2199659167.py:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s1.append(s2)   #It will bring both the series together
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# ...

# %% [markdown]
# #### if we multiply a list with a integer ( l*2 : it will double the list)
# But this multiplication will not work with the series

# %%
# Now  delete some colume of the dataframe

# %%
df.drop('PassengerId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df.drop('PassengerId')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %% [markdown]
# ### Why it is not deleting an column. What is axis coming in the error?
# #### The attribute of drop is having axis which is '0' bydefault.
# #### 0 means x- axis (rows) 1 means y-axis (columns)
# #### The 'Passenger_Id' is a column is present in 1 thatwhy it is giving this error

# %%
df.drop('PassengerId',axis=1)  #This deletion is not permanent(It is only dropping in the runtime)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# If we have to drop it permanently then use inplace = True in the attribute of the drop
df.drop('PassengerId',axis=1,inplace=True)

# %%
df  #dropped permanently
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#drop row from ddtaframe now
df.drop(3)  #Index
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df  #If inplace is not equal to true the deletion will be temprory
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#How to make a column data as a index
df.set_index('Name')
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df   #This index setting is not permanent
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index('Name',inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
#Now extract data using this index name
df.loc['Graham, Miss. Margaret Edith']   # it  always considers the named indices
# Out:
# Survived         1
# Pclass           1
# Sex         female
# Age           19.0
# SibSp            0
# Parch            0
# Ticket      112053
# Fare          30.0
# Cabin          B42
# Embarked         S
# Name: Graham, Miss. Margaret Edith, dtype: object

# %%
df.iloc[3]   #it always considers in-built indices
# Out:
# Survived         0
# Pclass           3
# Sex           male
# Age           35.0
# SibSp            0
# Parch            0
# Ticket      373450
# Fare          8.05
# Cabin          NaN
# Embarked         S
# Name: Allen, Mr. William Henry, dtype: object

# %%
#Now we want to get back to the normal indexes 
df.reset_index()
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Allen, Mr. William Henry                                   0       3    male
# Moran, Mr. James                                           0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3                             Allen, Mr. William Henry         0       3
# 4                                     Moran, Mr. James         0       3
# ..                                                 ...       ...     ...
# 885                              Montvila, Rev. Juozas         0       2
# 886                       Graham, Miss. Margaret Edith         1       1
# 887           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 888                              Behr, Mr. Karl Howell         1       1
# 889                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#Now Make a dictionery of same length 
d={
    "key1":[1,2,3,4],
    "key2":[4,5,6,7],
    "key3":[4,6,4,5]}

# %%
pd.DataFrame(d)   #this will convert the dictionery into the dataframe

# %%
d={
    "key1":[1,2,3,4,5],   
    "key2":[4,5,6,7],
    "key3":[4,6,4,5]}

# %%
pd.DataFrame(d)   #The dictionery must be of same length otherwise it will give an error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 pd.DataFrame(d)   #The dictionery must be of same length otherwise it will give an error
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# ...

# %%
# This will also work fine with the tuple values 
d={
    "key1":(1,2,3,4),   
    "key2":(3,5,6,7),
    "key3":(4,6,4,5)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     3     4
# 1     2     5     6
# 2     3     6     4
# 3     4     7     5

# %%
import pandas as pd
df=pd.read_csv("taxonomy.csv")

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# There are various missing dataset 
# drop the row or column of the missing value

# %%
df.dropna()   # drop the row value
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
# drop the column with the missing value 
df.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
#None of the drop is permanent until we use inplace=True

# %%
df
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# We can also fill the missing value with some value 
df.fillna("Deepa")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency     Deepa                 Deepa
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df # This is also not permanent util inplace =True
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# #### Groupby function : Bring thw similar data together

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.groupby('Survived') # It gives the object

# %%
# What is the average fare paid by people who died and people who survived
df.groupby('Survived').mean()
# Out:
# /tmp/ipykernel_1343/144429818.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
# WHat is the sum of  fare paid by people who died and people who survived
df.groupby('Survived').sum()
# Out:
# /tmp/ipykernel_1343/2206294047.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').sum()
#           PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199
# 1              151974     667   8219.67    162    159  16551.2294

# %%
 ## What is the total revenue paid by women and what renueue paid by men
df.groupby('Sex').sum()['Fare']
# Out:
# /tmp/ipykernel_1343/2538581414.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').sum()['Fare']
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
 ## What is the average age of women and men
df.groupby('Sex').mean()['Age']
# Out:
# /tmp/ipykernel_1343/2577454852.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').mean()['Age']
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
## What average booking done by class 1,class 2 ,class 3 passengers
df.groupby('Pclass').mean()['Fare']
# Out:
# /tmp/ipykernel_1343/3349489292.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Pclass').mean()['Fare']
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64

# %%
df3=df.groupby('Pclass').mean()
# Out:
# /tmp/ipykernel_1343/3282825724.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3=df.groupby('Pclass').mean()

# %%
#Now rotate the data outcomes
df3.T     #Transpose operation
# Out:
# Pclass                1           2           3
# PassengerId  461.597222  445.956522  439.154786
# Survived       0.629630    0.472826    0.242363
# Age           38.233441   29.877630   25.140620
# SibSp          0.416667    0.402174    0.615071
# Parch          0.356481    0.380435    0.393075
# Fare          84.154687   20.662183   13.675550

# %%
df3
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df3.transpose()   #Transpose operation
# Out:
# Pclass                1           2           3
# PassengerId  461.597222  445.956522  439.154786
# Survived       0.629630    0.472826    0.242363
# Age           38.233441   29.877630   25.140620
# SibSp          0.416667    0.402174    0.615071
# Parch          0.356481    0.380435    0.393075
# Fare          84.154687   20.662183   13.675550

# %%
df4=df[['PassengerId','Survived','Age']][0:5]

# %%
df4
# Out:
#    PassengerId  Survived   Age
# 0            1         0  22.0
# 1            2         1  38.0
# 2            3         1  26.0
# 3            4         1  35.0
# 4            5         0  35.0

# %%
df5=df[['PassengerId','Survived','Age']][4:10]

# %%
df5
# Out:
#    PassengerId  Survived   Age
# 4            5         0  35.0
# 5            6         0   NaN
# 6            7         0  54.0
# 7            8         0   2.0
# 8            9         1  27.0
# 9           10         1  14.0

# %%
## Now cancatinate both the dataframe
## We can cancatinate the dataframe in both horizonatal and vertical direction

# %%
pd.concat([df4,df5])   #If there is some common dataset then it will concate and become twice in the final dataset
# Horizontal cancatination
# Out:
#    PassengerId  Survived   Age
# 0            1         0  22.0
# 1            2         1  38.0
# 2            3         1  26.0
# 3            4         1  35.0
# 4            5         0  35.0
# 4            5         0  35.0
# 5            6         0   NaN
# 6            7         0  54.0
# 7            8         0   2.0
# 8            9         1  27.0
# 9           10         1  14.0

# %%
#vertical cancatination
pd.concat([df4,df5],axis=1)  
#It will place NaN in mismatch columns because index is not same
# Out:
#    PassengerId  Survived   Age  PassengerId  Survived   Age
# 0          1.0       0.0  22.0          NaN       NaN   NaN
# 1          2.0       1.0  38.0          NaN       NaN   NaN
# 2          3.0       1.0  26.0          NaN       NaN   NaN
# 3          4.0       1.0  35.0          NaN       NaN   NaN
# 4          5.0       0.0  35.0          5.0       0.0  35.0
# 5          NaN       NaN   NaN          6.0       0.0   NaN
# 6          NaN       NaN   NaN          7.0       0.0  54.0
# 7          NaN       NaN   NaN          8.0       0.0   2.0
# 8          NaN       NaN   NaN          9.0       1.0  27.0
# 9          NaN       NaN   NaN         10.0       1.0  14.0

# %%
data1=pd.DataFrame({
    "Key1":[1,2,4,5,4],
    "Key2":[2,3,4,8,7],
    "Key3":[7,5,5,4,5]})

# %%
data1
# Out:
#    Key1  Key2  Key3
# 0     1     2     7
# 1     2     3     5
# 2     4     4     5
# 3     5     8     4
# 4     4     7     5

# %%
data2=pd.DataFrame({
    "Key1":[8,5,3,5,1],
    "Key4":[2,5,6,6,8],
    "Key5":[7,5,2,4,4]})

# %%
data2
# Out:
#    Key1  Key4  Key5
# 0     8     2     7
# 1     5     5     5
# 2     3     6     2
# 3     5     6     4
# 4     1     8     4

# %% [markdown]
# #### Merge operation (INTERSECTION)

# %%
pd.merge(data1,data2)   
# In merge operation it will display only the common values of both datasets
# In this if there is a common column then print the all common possible
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     2     7     8     4
# 1     5     8     4     5     5
# 2     5     8     4     6     4

# %%
pd.merge(data1,data2,how='left') 
# data1 is left data2 is right (left is complete whatever match in right write correspond value o/w NaN)
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     2     7   8.0   4.0
# 1     2     3     5   NaN   NaN
# 2     4     4     5   NaN   NaN
# 3     5     8     4   5.0   5.0
# 4     5     8     4   6.0   4.0
# 5     4     7     5   NaN   NaN

# %%
pd.merge(data1,data2,how='right') 
# data1 is left data2 is right (right is complete whatever match in left write correspond value o/w NaN)
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     8   NaN   NaN     2     7
# 1     5   8.0   4.0     5     5
# 2     3   NaN   NaN     6     2
# 3     5   8.0   4.0     6     4
# 4     1   2.0   7.0     8     4

# %%
pd.merge(data1,data2,how='inner')   #The by-default merge operation is inner
# It takes common from both left and right
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1     2     7     8     4
# 1     5     8     4     5     5
# 2     5     8     4     6     4

# %%
pd.merge(data1,data2,how='outer') 
# It takes everything from both left and right and put NaN if not presnt in the other dataset
# Out:
#    Key1  Key2  Key3  Key4  Key5
# 0     1   2.0   7.0   8.0   4.0
# 1     2   3.0   5.0   NaN   NaN
# 2     4   4.0   5.0   NaN   NaN
# 3     4   7.0   5.0   NaN   NaN
# 4     5   8.0   4.0   5.0   5.0
# 5     5   8.0   4.0   6.0   4.0
# 6     8   NaN   NaN   2.0   7.0
# 7     3   NaN   NaN   6.0   2.0

# %%
pd.merge(data1,data2,how='cross') 
# It takes every data from first and merge with everything of the second
# Out:
#     Key1_x  Key2  Key3  Key1_y  Key4  Key5
# 0        1     2     7       8     2     7
# 1        1     2     7       5     5     5
# 2        1     2     7       3     6     2
# 3        1     2     7       5     6     4
# 4        1     2     7       1     8     4
# 5        2     3     5       8     2     7
# 6        2     3     5       5     5     5
# 7        2     3     5       3     6     2
# 8        2     3     5       5     6     4
# 9        2     3     5       1     8     4
# 10       4     4     5       8     2     7
# 11       4     4     5       5     5     5
# 12       4     4     5       3     6     2
# 13       4     4     5       5     6     4
# 14       4     4     5       1     8     4
# 15       5     8     4       8     2     7
# 16       5     8     4       5     5     5
# 17       5     8     4       3     6     2
# 18       5     8     4       5     6     4
# 19       5     8     4       1     8     4
# 20       4     7     5       8     2     7
# ...

# %%
#What if there is nothing common in 2 datasets?
import pandas as pd
data3=pd.DataFrame({
    "Key1":[1,2,3],
    "key2":[2,7,5]})

# %%
data3
# Out:
#    Key1  key2
# 0     1     2
# 1     2     7
# 2     3     5

# %%
data4=pd.DataFrame({
    "Key3":[1,2,3],
    "key4":[1,2,3]})

# %%
data4
# Out:
#    Key3  key4
# 0     1     1
# 1     2     2
# 2     3     3

# %%
pd.merge(data3,data4)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 pd.merge(data3,data4)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
# ...

# %%
#How to merge with different keys then
pd.merge(data3,data4,how='left',left_on='key2',right_on='key4')
# Out:
#    Key1  key2  Key3  key4
# 0     1     2   2.0   2.0
# 1     2     7   NaN   NaN
# 2     3     5   NaN   NaN

# %% [markdown]
# #### Join operation  :
# Difference b/w merge and join
#
# In merge it tries to match columnwise while in join it tries to match indices(row)

# %%
#Create 2 datasets with their own custom indices

# %%
dataj1=pd.DataFrame({ "key1":[1,2,4,5,6],
                     "key2":[4,5,6,7,8],
                     "key3":[3,4,5,6,6]},
                    index=['a','b','c','d','e'])

# %%
dataj1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
dataj2=pd.DataFrame({ "key11":[1,2,4,5,6],
                     "key22":[4,5,6,7,8],
                     "key33":[3,4,5,6,6]},
                    index=['a','b','h','i','j'])

# %%
dataj2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %%
dataj1.join(dataj2)   #Bydefault join by left
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
dataj1.join(dataj2,how='inner')  #Givee only the common values
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
dataj1.join(dataj2,how='outer')  #Take every values from both datasets and place NaN accordingly
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
dataj1.join(dataj2,how='right')  # Check with dataj2
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      4      6      5
# i   NaN   NaN   NaN      5      7      6
# j   NaN   NaN   NaN      6      8      6

# %%
dataj1.join(dataj2,how='cross')  #Give all possible joins
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      4      6      5
# 3      1     4     3      5      7      6
# 4      1     4     3      6      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      4      6      5
# 8      2     5     4      5      7      6
# 9      2     5     4      6      8      6
# 10     4     6     5      1      4      3
# 11     4     6     5      2      5      4
# 12     4     6     5      4      6      5
# 13     4     6     5      5      7      6
# 14     4     6     5      6      8      6
# 15     5     7     6      1      4      3
# 16     5     7     6      2      5      4
# 17     5     7     6      4      6      5
# 18     5     7     6      5      7      6
# 19     5     7     6      6      8      6
# 20     6     8     6      1      4      3
# ...

# %%
#What if there is nothing matches in both

# %%
data3=pd.DataFrame({
    "Key1":[1,2,3],
    "key2":[2,7,5]},
index=['d','e','f'])

# %%
data3
# Out:
#    Key1  key2
# d     1     2
# e     2     7
# f     3     5

# %%
data4=pd.DataFrame({
    "Key3":[1,2,3],
    "key4":[1,2,3]},
index=['a','b','c'])

# %%
data4
# Out:
#    Key3  key4
# a     1     1
# b     2     2
# c     3     3

# %%
#No index is common now perform join
data3.join(data4)   #It is not giving an error (by-default left)
# Out:
#    Key1  key2  Key3  key4
# d     1     2   NaN   NaN
# e     2     7   NaN   NaN
# f     3     5   NaN   NaN

# %%
data3.join(data4,how='inner')   #Still not giving error instead blank output
# Out:
# Empty DataFrame
# Columns: [Key1, key2, Key3, key4]
# Index: []

# %%
#Now 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Make a new column and write the INR value of the fare into that column as euro value of fare ig given
#Apply function  :It is just like a map function

# %%
df['Fare_inr1']=df['Fare'].apply(lambda x:x*80)  #This apply function will work on each and every function

# %%
df.head()  # One column
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_inr  Len_name  \
# 0      0         A/5 21171   7.2500   NaN        S   580.000        23
# 1      0          PC 17599  71.2833   C85        C  5702.664        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000        22
# ...

# %%
# Other way
def inr_val(x):
    return x*80
df['Fare_inr2']=df['Fare'].apply(inr_val)  #Other column

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_inr  Len_name  \
# 0      0         A/5 21171   7.2500   NaN        S   580.000        23
# 1      0          PC 17599  71.2833   C85        C  5702.664        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000        22
# ...

# %%
# Make a new column as write the calculated length value of every element in the name column
df['Len_name']=df['Name'].apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare_inr  Len_name
# 0      0         A/5 21171   7.2500   NaN        S   580.000        23
# 1      0          PC 17599  71.2833   C85        C  5702.664        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S   634.000        22
# ...

# %%
# Make diiferent category according to the different money spend
def flag_cate(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid"
    else:
        return "High"

# %%
df['Flag_category']=df['Fare'].apply(flag_cate)

# %%
df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...
