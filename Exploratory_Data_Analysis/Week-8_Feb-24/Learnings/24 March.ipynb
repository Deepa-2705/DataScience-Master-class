# %% [markdown]
# ### EDA with Red Wine Datasets

# %%
import pandas as pd
df=pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info() # it gives all the feature the dataset is having
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe()  # it gives the information of desriptive statistical
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.shape  # npo of columns and rows
# Out:
# (1599, 12)

# %%
df.columns   # gives names of all the columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df['quality'].unique()  # gives all the unique value of the column
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# check whether there is some missing values in the dataset
df.isnull().sum()   # every column sum is 0 it means the dataset does not contain any missing values
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# if 2 or more rows contain duplicate values then performing operation on every rows is of no use 
df[df.duplicated()]  # 240 rows contains duplicate value
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %%
# remove duplicates (duplicates dont play a important role 
df.drop_duplicates(inplace=True)

# %%
df.shape  # 240 duplicates rows gets deleted
# Out:
# (1359, 12)

# %%
# correlation
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
# correlation in visualization
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
# The values above are very combersome so increase the fig size to more visibility
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
# more visualization
df['quality'].value_counts()  # the 5 value comes large no of times then other so it is imbalanced datasets
# conclusion: wine datasets is a imbalanced datasets
# Out:
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: quality, dtype: int64

# %%
df['quality'].value_counts().plot(kind='bar')  # visualization of the imbalaced nature
plt.xlabel('Wine Quality')
plt.ylabel('Count')
plt.show()

# %%
# Check the distribution of each and every columns present in the datasets
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
for column in df.columns:
    sns.histplot(df[column],kde=True)

# %%
# check distribution of particular dataset
sns.histplot(df['alcohol'],kde=True)
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='Count'>

# %%
# Pairplot used for univariate.bivariate,multivariate analysis (show how one feature dependent with all other feature)
# sns.pairplot(df)  # This take some large time and also file saving is difficult to I comment this count

# %%
# categorical plot 
sns.catplot(x='quality',y='alcohol',data=df,kind='box')

# %%
# Scatter plot is usually used with the numerical feature
sns.scatterplot(x='alcohol',y='pH',hue='quality',data=df)
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='pH'>

# %% [markdown]
# ### Perform EDA on another dataset

# %% [markdown]
# EDA Student Performance Indicator
#
# 1) Problem statement
#
# This project understands how the student's performance (test scores) is affected by other variables such as Gender, Ethnicity, Parental level of education, Lunch and Test preparation course.
#
# 2) Data Collection
#
# Dataset Source - https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?datasetId=74977
#
# The data consists of 8 column and 1000 rows.
#
# 3) Dataset Information
#
# gender : sex of students -> (Male/female)
#
# race/ethnicity : ethnicity of students -> (Group A, B,C, D,E)
#
# parental level of education : parents' final education ->(bachelor's degree,some college,master's degree,associate's degree,high school)
#
# lunch : having lunch before test (standard or free/reduced)
#
# test preparation course : complete or not complete before test
#
# math score
#
# reading score
#
# writing score

# %% [markdown]
# ### 3. Data Checks to perform
#
# Check Missing values
#
# Check Duplicates
#
# Check data type
#
# Check the number of unique values of each column
#
# Check statistics of data set
#
# Check various categories present in the different categorical column

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings   # import this library to remove the warning
warnings.filterwarnings('ignore')

# %%
# read the csv 
df=pd.read_csv('stud.csv')
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# ### Check missing values

# %%
# df.isnull().sum() 
# other way 
df.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# ### Insights or observation:
# every value is 0 so there is no missing values in the dataset

# %% [markdown]
# ### Check duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Insights or observation:
# There is no duplicate value

# %% [markdown]
# ### Check Datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ### Check no. of unique value of every column

# %%
df.nunique()
# Out:
# gender                          2
# race_ethnicity                  5
# parental_level_of_education     6
# lunch                           2
# test_preparation_course         2
# math_score                     81
# reading_score                  72
# writing_score                  77
# dtype: int64

# %% [markdown]
# ### Check the statistics info of the datasets

# %%
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #### If the standard deviation contain close values for various column then they shows almost similar distribution

# %% [markdown]
# ### Insights and observation
# * From the above description of numerical data, all means are very close to each other- between 66 to 69
# * All the standard deviation are very close- between 14.6 - 15.19
# * The minimum for maths is 0 and the minimum of other is 17 and 10

# %%
# Explore more info about the data 
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# Print all feature of the every columns if the datatype of that feature is not an object(notation : capital O) 
[feature for feature in df.columns if df[feature].dtype!='O']
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
# Segrregate numerical and categorical features 
numerical_features=[feature for feature in df.columns if df[feature].dtype!='O']
categorical_features=[feature for feature in df.columns if df[feature].dtype=='O']

# %%
numerical_features
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
categorical_features
# Out:
# ['gender',
#  'race_ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course']

# %% [markdown]
# ### Create 2 more features of total_score and average_score

# %%
df['total_score']=df['math_score']+df['writing_score']+df['reading_score']

# %%
df['avg_score']=df['total_score']/3

# %%
df.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  avg_score
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# ### Explore more visualization

# %%
fig,axis=plt.subplots(1,2,figsize=(15,7))  # 1 row and 2 column and figure size
plt.subplot(121)  # display the data in the first box 
sns.histplot(data=df,x='avg_score',bins=30,kde=True,color='g') # We will observe how the average score looks like
plt.subplot(122)  
sns.histplot(data=df,x='avg_score',bins=30,kde=True,hue='gender')
plt.show()  # We are observing how the average score resmbles on the basis of gender(check who is performing well)

# %% [markdown]
# ### Insights and observation
# * Female students tends to perform well than male students

# %%
# Check wether the lunch perform important role wrt to average or not
# plt.subplots(1,3,figsize=(25,6))  # 1 row and 2 column and figure size
# plt.subplot(141)  # display the data in the first box 
# sns.histplot(data=df,x='avg_score',kde=True,hue='lunch') # We will observe how the average score looks like
# plt.subplot(142)  
# sns.histplot(data=df[df.gender=='female'],x='avg_score',kde=True,hue='lunch')
# plt.subplot(143)  
# sns.histplot(data=df[df.gender=='male'],x='avg_score',kde=True,hue='lunch')
# plt.show()

# %% [markdown]
# ### Insights and observation:
# * Standard lunch helps students to perfrom well in the exam
# * Standard lunch helps students to perfrom well in the exam in case of both male and female

# %%
# Check wether the parental_level_of_education perform important role wrt to average or not
# plt.subplots(1,3,figsize=(25,6))  # 1 row and 2 column and figure size
# plt.subplot(141)  # display the data in the first box 
# sns.histplot(data=df,x='avg_score',kde=True,hue='parental_level_of_education') # We will observe how the average score looks like
# plt.subplot(142)  
# sns.histplot(data=df[df.gender=='male'],x='avg_score',kde=True,hue='parental_level_of_education')
# plt.subplot(143)  
# sns.histplot(data=df[df.gender=='female'],x='avg_score',kde=True,hue='parental_level_of_education')
# plt.show()

# %% [markdown]
# ### Insights and Observation
# * In general parent's education does not help student perform well in exam
# * 2nd slot shows that whose parent's education is of associate's degree or master's degree their male child tend to well in the exam.(Because graph of the associate and the master degree is left skewed so average graph is also left skewed)
# * In the 3rd slot we can see that there is no effect of parent's education on the female students

# %%
# Check wether the race_ethicinity perform important role wrt to average or not
# plt.subplots(1,3,figsize=(25,6))  # 1 row and 2 column and figure size
# plt.subplot(141)  # display the data in the first box 
# sns.histplot(data=df,x='avg_score',kde=True,hue='race_ethnicity') # We will observe how the average score looks like
# plt.subplot(142)  
# sns.histplot(data=df[df.gender=='male'],x='avg_score',kde=True,hue='race_ethnicity')
# plt.subplot(143)  
# sns.histplot(data=df[df.gender=='female'],x='avg_score',kde=True,hue='race_ethnicity')
# plt.show()

# %% [markdown]
# ### Insights and observation
# * The students of group A and B is not performing well in the exam (Because the graph is right skewed so the average graph is also right skewed)
# * The students of group A and B is not performing well in the exam irrespective of the male and female (Because the graph is right skewed of both male and female)

# %%
# sns.pairplot(df)

# %%
# sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# ### Insights:
# * all the columns are highly correlated
