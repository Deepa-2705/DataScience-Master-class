# %% [markdown]
# Q1. What are the key features of the wine quality data set? Discuss the importance of each feature in
# predicting the quality of wine.
#
# Ans:
# * Input variables (based on physicochemical tests):
#
# 1 - fixed acidity
# 2 - volatile acidity
# 3 - citric acid
# 4 - residual sugar
# 5 - chlorides
# 6 - free sulfur dioxide
# 7 - total sulfur dioxide
# 8 - density
# 9 - pH
# 10 - sulphates
# 11 - alcohol
#
# * Output variable (based on sensory data):
#
# 12 - quality (score between 0 and 10)
#
# In general, using Model 3 as our best model for prediction, I determined four of the features as the most influential: volatile acidity, citric acid, sulphates, and alcohol. To be more specific, high-quality wines seem to have lower volatile acidity, higher alcohol, and medium-high sulphate values.

# %% [markdown]
# Q2. How did you handle missing data in the wine quality data set during the feature engineering process?
# Discuss the advantages and disadvantages of different imputation techniques.
#
# Ans: There is no missing value in the wine quality datasets.
#
# 1. Complete Case Analysis(CCA)
#
# This is a quite straightforward method of handling the Missing Data, which directly removes the rows that have missing data i.e we consider only those rows where we have complete data i.e data is not missing. This method is also popularly known as “Listwise deletion”.
#
# * Advantages:-
#
# Easy to implement.
#
# No Data manipulation required.
#
# * Limitations:-
#
# Deleted data can be informative.
#
# Can lead to the deletion of a large part of the data.
#
# Can create a bias in the dataset, if a large amount of a particular type of variable is deleted from it.
#
# The production model will not know what to do with Missing data.
#
# 2. Arbitrary Value Imputation
#
# This is an important technique used in Imputation as it can handle both the Numerical and Categorical variables. This technique states that we group the missing values in a column and assign them to a new value that is far away from the range of that column. Mostly we use values like 99999999 or -9999999 or “Missing” or “Not defined” for numerical & categorical variables.
#
# * Advantages:-
#
# Easy to implement.
#
# We can use it in production.
#
# It retains the importance of “missing values” if it exists.
#
# * Disadvantages:-
#
# Can distort original variable distribution.
#
# Arbitrary values can create outliers.
#
# Extra caution required in selecting the Arbitrary value.
#
# 3. Frequent Category Imputation
#
# This technique says to replace the missing value with the variable with the highest frequency or in simple words replacing the values with the Mode of that column. This technique is also referred to as Mode Imputation.
#
# * Advantages:-
#
# Implementation is easy.
#
# We can obtain a complete dataset in very little time.
#
# We can use this technique in the production model.
#
# * Disadvantages:-
#
# The higher the percentage of missing values, the higher will be the distortion.
#
# May lead to over-representation of a particular category.
#
# Can distort original variable distribution.
#
# 4. statistical Values imputation
#
# This is done using statistical values like mean, median. However, none of these guarantees unbiased data, especially if there are many missing values.
#
# Mean is most useful when the original data is not skewed, while the median is more robust, not sensitive to outliers, and thus used when data is skewed.
#
# In a normally distributed data, one can get all the values that are within 2 standard deviations from the mean. Next, fill in the missing values by generating random numbers between (mean — 2 std) & (mean + 2 std)
#
# 5. Using a linear regression.
#
# Based on the existing data, one can calculate the best fit line between two variables, from checking correlations.
#
# It is worth mentioning that linear regression models are sensitive to outliers.

# %%
import pandas as pd

# %%
df=pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.isna().sum()   # no missing value
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Q3. What are the key factors that affect students' performance in exams? How would you go about
# analyzing these factors using statistical techniques?
#
# Ans: All factors are:
#
# 1) AS – Average score
# 2) Race – Whether the student is white, black or Hispanic;
# 3) Male – 1 if male, 0 if female;
# 4) ParEd – Parents Education by Category;
# 5) HoursKids – Time parents spend with kids, in hours;
# 6) GradestImport – Where parents believe that grades are important (1 = important);
# 7) Attend – How many times the student attends the afterschool event;
# 8) HourStudy – How much time student studies at home (in hours);
# 9) Sports – 1 if a student plays sports, otherwise 0

# %% [markdown]
# Q4. Describe the process of feature engineering in the context of the student performance data set. How
# did you select and transform the variables for your model?
#
# Ans: Feature engineering is a crucial step in machine learning that involves selecting, transforming, and creating new features (variables) from the existing data to improve the performance of a predictive model. In the context of a student performance dataset, the goal is to prepare the data in a way that allows a machine learning model to effectively predict student outcomes, such as their grades or academic success.
#
# Here is a general process for feature engineering in the context of a student performance dataset:
#
# 1) Data Collection and Understanding:
#
# Begin by collecting and importing the student performance dataset, which typically includes information such as student demographics (e.g., age, gender), educational background (e.g., previous grades, parental education), and academic performance (e.g., scores in various subjects).
#
# Understand the dataset's structure, including the types of variables (categorical, numerical) and the target variable (what you want to predict, e.g., final grades).
#
# 2) Data Cleaning:
#
# Handle missing data by either imputing missing values or removing rows/columns with excessive missing data.
# Address any outliers or anomalies in the data that could affect model performance.
#
# 3) Feature Selection:
#
# Identify which features are relevant for predicting student performance. This step involves domain knowledge and exploratory data analysis (EDA). For example:
#
# You might find that certain demographic features (e.g., age, gender) are not highly predictive of academic performance and can be excluded.
#
# Academic-related features like previous exam scores or study time might be more relevant.
#
# 4) Feature Transformation:
#
# Convert categorical variables into numerical representations using techniques like one-hot encoding or label encoding.
# Normalize or scale numerical features to ensure they have similar scales, which can improve the performance of some machine learning algorithms.
#
# Create new features if they provide additional insights. For instance, you might calculate the average score across all subjects for each student or create binary features based on certain thresholds (e.g., high vs. low study time).
#
# 5) Feature Engineering Techniques:
#
# Polynomial features: Introduce polynomial features to capture non-linear relationships between variables.
# Binning: Group continuous variables into bins or categories to simplify the relationship.
#
# Interaction features: Create interaction terms by multiplying or combining two or more features to capture potential interactions.
#
# 6) Feature Scaling:
#
# Scale or standardize the features to ensure that they have similar ranges. Common techniques include Min-Max scaling or Z-score standardization.
#
# 7) Feature Importance:
#
# Use feature importance techniques like feature importance scores from tree-based models or correlation analysis to identify which features have the most impact on the target variable.
#
# 8) Dimensionality Reduction (if necessary):
#
# Apply dimensionality reduction techniques like Principal Component Analysis (PCA) or feature selection methods like Recursive Feature Elimination (RFE) if you have a large number of features and want to reduce model complexity.
# Model Evaluation:
#
# Continuously assess the impact of feature engineering on model performance through cross-validation and model evaluation metrics. You may need to iterate on feature engineering based on the model's performance.
#
# 9) Documentation:
#
# Keep detailed records of all feature engineering steps and transformations applied to the data for reproducibility.
# The specific feature engineering steps you take will depend on the dataset, the machine learning algorithms you plan to use, and your domain knowledge. It's an iterative process that often involves experimenting with different feature sets and transformations to optimize model performance for predicting student outcomes in this case.

# %% [markdown]
# Q5. Load the wine quality data set and perform exploratory data analysis (EDA) to identify the distribution
# of each feature. Which feature(s) exhibit non-normality, and what transformations could be applied to
# these features to improve normality?

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Display basic statistics of the dataset
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Plot histograms to visualize the distribution of each feature
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 8))
for i, column in enumerate(df.columns):
    plt.subplot(3, 4, i+1)
    sns.histplot(df[column], kde=True)
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# Now, let's interpret the results of the EDA and identify which feature(s) exhibit non-normality:
#
# 1) Fixed Acidity: The distribution appears slightly right-skewed, meaning it's not perfectly normal. You can consider transformations like log or square root to make it more symmetric.
#
# 2) Volatile Acidity: This feature also exhibits right-skewness. Applying a log or square root transformation could improve normality.
#
# 3) Citric Acid: The distribution seems to be closer to normal, but it has a small left tail. You might apply transformations to see if it can be improved.
#
# 4) Residual Sugar: This feature is right-skewed, and it might benefit from a log or square root transformation.
#
# 5) Chlorides: Similar to the previous features, this one is right-skewed. Log or square root transformations could be helpful.
#
# 6) Free Sulfur Dioxide: The distribution appears to have a long right tail. Applying a log or square root transformation might help.
#
# 7) Total Sulfur Dioxide: This feature also exhibits a long right tail. A log or square root transformation can be considered.
#
# 8) Density: The distribution appears to be quite normal, with a slight peak near the center.
#
# 9) pH: The distribution is roughly normal, but there's a slight skewness towards the left.
#
# 10) Sulphates: The distribution is somewhat normal, but there's a slight right-skewness.
#
# 11) Alcohol: The distribution appears to be roughly normal, with a peak around the center.
#
# When deciding on transformations to improve normality, you can try various techniques, including:
#
# * Log Transformation: This can help with right-skewed data.
# * Square Root Transformation: Similar to log transformation, it can make right-skewed data more normal.
# * Box-Cox Transformation: It's a power transformation that can handle different types of skewness.
# * Exponential Transformation: This can be applied to left-skewed data.
#
# After applying transformations, it's essential to reevaluate the distributions and check if they are closer to normality. Keep in mind that the choice of transformation may depend on the specific requirements of your analysis or the machine learning models you plan to use.

# %% [markdown]
# Q6. Using the wine quality data set, perform principal component analysis (PCA) to reduce the number of
# features. What is the minimum number of principal components required to explain 90% of the variance in
# the data?

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load the wine quality dataset
wine_data = pd.read_csv("winequality-red.csv")

# Separate features (X) and target variable (y)
X = wine_data.drop("quality", axis=1)

# Standardize the feature matrix
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Calculate the explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Calculate cumulative explained variance
cumulative_explained_variance = np.cumsum(explained_variance_ratio)

# Determine the number of components needed to explain 90% of the variance
n_components = np.argmax(cumulative_explained_variance >= 0.90) + 1

# Print the results
print(f"Number of components needed to explain 90% of variance: {n_components}")
# Out:
# Number of components needed to explain 90% of variance: 7

# %% [markdown]
# In this code:
#
# 1) We load the wine quality dataset and separate the features (X) from the target variable (y).
#
# 2) We standardize the feature matrix using StandardScaler to ensure that all features have the same scale, which is a crucial step for PCA.
#
# 3) PCA is performed on the standardized feature matrix (X_scaled) using the PCA class from scikit-learn.
#
# 4) We calculate the explained variance ratio for each principal component. The explained variance ratio represents the proportion of the total variance in the data explained by each component.
#
# 5) We compute the cumulative explained variance by taking the cumulative sum of the explained variance ratios.
#
# 6) To determine the minimum number of principal components required to explain 90% of the variance, we find the index where the cumulative explained variance first exceeds or equals 90%. This index corresponds to the number of components needed.
#
# 7) Finally, we print the number of components required.
#
# The code will output the minimum number of principal components needed to explain 90% of the variance in the data. This reduced set of principal components can be used for further analysis or as input to machine learning models, effectively reducing the dimensionality of the data while retaining most of its information.
