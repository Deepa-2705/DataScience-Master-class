# %% [markdown]
# Q1. What is Statistics?
#
# Ans: Statistics is a science of collecting, organizing and analyzing the data.
#
# Ex:   Heights of students in a class ,Gender etc.

# %% [markdown]
# Q2. Define the different types of statistics and give an example of when each type might be used.
#
# Ans: Types of statistics:
#
# 1) Decriptive Statistics: It consists of organizing and summarizing the data
#
#
#    Use :
#    Measure of central tendency
#    Measure of dispersion
#    Histogram ,bar charts ,pie chart
#
# 2) Inferential statistics: It consists of using data for measurement to from conclusions.
#    Use :
#    x-test, t-test, z-test, Hypothesis testing, p value, significance

# %% [markdown]
# Q3. What are the different types of data and how do they differ from each other? Provide an example of
# each type of data.
#
# Ans: Types of data :
#
# 1) Qalitative data : (It contains numeric data )
#
#       a) discrete  (It contains whole numbers)
#
#           eg: No. of cities in a state
#
#       b) continues (It contians any values on the number line)
#
#           eg: Height, weight
#
# 2) Qualitative data: (It contains categorical data)
#
#       a) Nominal (It contains categores with fixed size)
#
#           eg: Gender, Marital Status
#
#       b) Ordinal (It contains categories which can be ranked)
#
#           eg: Reviews: Good, Bad, Excellent

# %% [markdown]
# Q4. Categorise the following datasets with respect to quantitative and qualitative data types:
#
# (i) Grading in exam: A+, A, B+, B, C+, C, D, E
#
# (ii) Colour of mangoes: yellow, green, orange, red
#
# (iii) Height data of a class: [178.9, 179, 179.5, 176, 177.2, 178.3, 175.8,...]
#
# (iv) Number of mangoes exported by a farm: [500, 600, 478, 672, ...]
#
# Ans:
#
# (i) Quantitative
#
# (ii) Qualitative
#
# (iii) Quantitative
#
# (iv) Qualitative

# %% [markdown]
# Q5. Explain the concept of levels of measurement and give an example of a variable for each level.
#
# Ans: Types of Level of measurement :
#
# 1) Nominal level :
#    * Qualitative / categorical variable
#    * Order does not matters
#    * eg: Nationality
#
# 2) Ordinal level :
#    * Ranking and order matters
#    * Difference cannot be measured
#    * eg: Winners of the race
#
# 3) Interval level:
#    * The rank and the order matters
#    * Difference can be measured (excluding ratio)
#    * Does not have a 0 starting value
#    * eg: Humidity level
#
# 4) Ratio level:
#    * The rank and the order matters
#    * Difference and ration can be measured
#    * Does have a 0 starting value
#    * eg: Age of group of person (0 age for new born)

# %% [markdown]
# Q6. Why is it important to understand the level of measurement when analyzing data? Provide an
# example to illustrate your answer.
#
# Ans: It is important to understand the level of measurement of variables in research, because the level of measurement determines the type of statistical analysis that can be conducted, and, therefore, the type of conclusions that can be drawn from the research.
#
# * nominal level:
#
# The variable of marital status may be measured by two categories, married and unmarried.
#
# * ordinal level:
#
# observations may be classified into categories such as taller and shorter, greater and lesser, faster and slower, harder and easier
#
# * interval level:
#
# The commonly used measures of temperature are interval level scales
#
# * ratio level:
#
# weight, area, speed, and velocity are measured on a ratio level scale

# %% [markdown]
# Q7. How nominal data type is different from ordinal data type.
#
# Ans:
#
# 1) Nominal level :
#    * Qualitative / categorical variable
#    * Order does not matters
#    * eg: Nationality
#
# 2) Ordinal level :
#    * Ranking and order matters
#    * Difference cannot be measured
#    * eg: Winners of the race

# %% [markdown]
# Q8. Which type of plot can be used to display data in terms of range?
#
# Ans: Histogram. If the groups depicted in a bar chart are actually continuous numeric ranges, we can push the bars together to generate a histogram. Bar lengths in histograms typically correspond to counts of data points, and their patterns demonstrate the distribution of variables in your data.

# %% [markdown]
# Q9. Describe the difference between descriptive and inferential statistics. Give an example of each
# type of statistics and explain how they are used.
#
# Ans: Difference:
#
# 1) Descriptive Statistics gives information about raw data regarding its description or features. Inferential statistics, on the other hand, draw inferences about the population by using data extracted from the population.
#
# 2) We use descriptive statistics to describe a situation, while we use inferential statistics to explain the probability of occurrence of an event.
#
# 3) As for descriptive statistics, it helps to organize, analyze and present data in a meaningful manner. Inferential statistics helps to compare data, make hypotheses and predictions.
#
# 4) Descriptive statistics explains already known data related to a particular sample or population of a small size. Inferential statistics, however, aims to draw inferences or conclusions about a whole population.
#
# 5) We use charts, graphs, and tables to represent descriptive statistics, while we use probability methods for inferential statistics.
#
# 6) It is simpler to perform a study using descriptive statistics rather than inferential statistics, where you need to establish a relationship between variables in an entire population.
#
#
# Examples of descriptive statistics are used to enumerate and explain a dataset's key characteristics. Measures like mean, median, mode, range, variance, and standard deviation are some examples. For instance, you could use descriptive statistics to determine the average age, the age distribution, and the age standard deviation of a group of individuals if you wanted to summarize their ages.
#
#
# Using a sample of data, inferential statistics is used to draw conclusions or generalizations about a broader population. Examples include regression analysis, confidence ranges, and hypothesis testing. For instance, you could use inferential statistics to assess whether there is a significant difference in the outcomes of patients who receive the drug compared to those who receive a placebo if you want to know if a new drug is effective.

# %% [markdown]
# Q10. What are some common measures of central tendency and variability used in statistics? Explain
# how each measure can be used to describe a dataset.
#
# Ans: Central tendency and variation are two measures used in statistics to summarize data. Measure of central tendency shows where the center or middle of the data set is located, whereas measure of variation shows the dispersion among data values.
#
# * <h4> Measures of Central Tendency:</h4>
#
# 1) Mean: average of data values
#
# E.g. Find the mean of following values: {2, 3, 5, 2, 4, 2,}
#
# Σ𝑥𝑥 = 2 + 3 + 5 + 2 + 4 + 2 =18; n = 6
#
# mean=6
#
# 2) Median: “middle value” or the average of “middle
#
# two values” in a data set when the numbers are
# arranged in an order.
#
# E.g. Find the median of following values: {2, 3, 5, 2, 4, 2}
#
# Median is 2.5
#
# (NB: If the ‘n’ is an odd number, then find the middle value after
# sorting the numbers in an order)
#
# 3) Mode: value that occurs with greatest frequency.
#
# E.g. Find the mode of following values:
# {2, 3, 5, 2, 4, 2}
#
# Most common number/Mode is 2.
#
# * <h4>Measures of variation:</h4>
#
# 1) Standard deviation: measure of how much data
#
# values are deviated away from mean.
#
# 2) Variance: square of the standard deviation.
#
# E.g. Find the standard deviation and variance of following values: {2, 3, 5, 2, 4, 2,}
#
# Standard deviation, s = 1; Variance, s2 = 1
#
# 3) Range: difference between the maximum value and
#
# Range = maximum value – minimum value
#
# E.g. Find the range of following values: {3, 2, 4}
#
# range= 4-2 = 2
