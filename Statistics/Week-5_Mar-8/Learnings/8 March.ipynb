# %% [markdown]
# ## Check Normal Distribution using QQ-Plot Quartile - Quartile plot

# %%
import scipy.stats as stat
import pylab
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#We will check for every features whether it belongs to normal distribution or not
import matplotlib.pyplot as plt

# %%
def plot_data(df,feature):   #using this function we will try to make some figure
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)    # no of plots
    # Create 2 figure one on left and one on right
    #left will show histogram or distribution and the right will show thw QQ plot
    # df[feature].hist() #Construct histogram
    sns.histplot(df[feature],kde=True)   #It   will looks like an normal distribution
    plt.subplot(1,2,2)
    stat.probplot(df[feature],dist='norm',plot=pylab)  # dist will compare x variable with other variable
    plt.show()

# %%
#How figure will come
plot_data(df,'sepal_width')

# %%
#We can observe if the right side diagram will come in a straight line then it will be a normal distribution
#In Q Q plot x axis has normal distribution and y axis has the feature value

# %%
plot_data(df,'petal_width')

# %%
#This is not a normal or gaussian distribution (points are not on a straight line)

# %%
plot_data(df,'sepal_length')

# %%
#This also follows the normal distribution

# %%
plot_data(df,'petal_length')

# %%
#This is not a normal or gaussian distribution

# %%
#Now another datasets

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plot_data(df,'total_bill')

# %%
#This looks like log normal distribution but tis is not a normal distribution

# %%
plot_data(df,'tip')

# %%
#not a normal distribution

# %%
plot_data(df,'sex')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 plot_data(df,'sex')
#
# Cell In[28], line 9, in plot_data(df, feature)
#       7 sns.histplot(df[feature],kde=True)   #It   will looks like an normal distribution
#       8 plt.subplot(1,2,2)
# ----> 9 stat.probplot(df[feature],dist='norm',plot=pylab)  # dist will compare x variable with other variable
#      10 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_morestats.py:614, in probplot(x, sparams, dist, fit, plot, rvalue)
#     611 osr = sort(x)
#     612 if fit:
#     613     # perform a linear least squares fit.
# --> 614     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     616 if plot is not None:
#     617     plot.plot(osm, osr, 'bo')
#
# ...

# %%
plot_data(df,'smoker')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 plot_data(df,'smoker')
#
# Cell In[28], line 9, in plot_data(df, feature)
#       7 sns.histplot(df[feature],kde=True)   #It   will looks like an normal distribution
#       8 plt.subplot(1,2,2)
# ----> 9 stat.probplot(df[feature],dist='norm',plot=pylab)  # dist will compare x variable with other variable
#      10 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_morestats.py:614, in probplot(x, sparams, dist, fit, plot, rvalue)
#     611 osr = sort(x)
#     612 if fit:
#     613     # perform a linear least squares fit.
# --> 614     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     616 if plot is not None:
#     617     plot.plot(osm, osr, 'bo')
#
# ...

# %%
plot_data(df,'day')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plot_data(df,'day')
#
# Cell In[28], line 9, in plot_data(df, feature)
#       7 sns.histplot(df[feature],kde=True)   #It   will looks like an normal distribution
#       8 plt.subplot(1,2,2)
# ----> 9 stat.probplot(df[feature],dist='norm',plot=pylab)  # dist will compare x variable with other variable
#      10 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_morestats.py:614, in probplot(x, sparams, dist, fit, plot, rvalue)
#     611 osr = sort(x)
#     612 if fit:
#     613     # perform a linear least squares fit.
# --> 614     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     616 if plot is not None:
#     617     plot.plot(osm, osr, 'bo')
#
# ...

# %%
plot_data(df,'time')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 plot_data(df,'time')
#
# Cell In[28], line 9, in plot_data(df, feature)
#       7 sns.histplot(df[feature],kde=True)   #It   will looks like an normal distribution
#       8 plt.subplot(1,2,2)
# ----> 9 stat.probplot(df[feature],dist='norm',plot=pylab)  # dist will compare x variable with other variable
#      10 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/scipy/stats/_morestats.py:614, in probplot(x, sparams, dist, fit, plot, rvalue)
#     611 osr = sort(x)
#     612 if fit:
#     613     # perform a linear least squares fit.
# --> 614     slope, intercept, r, prob, _ = _stats_py.linregress(osm, osr)
#     616 if plot is not None:
#     617     plot.plot(osm, osr, 'bo')
#
# ...

# %%
plot_data(df,'size')

# %%
#not a normal distribution
